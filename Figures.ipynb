# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import matplotlib.gridspec as gridspec

# %%
folder_path = r'C:\Users\PcLaptop\Desktop\EGT paper'
folder_path = r'/home/sara/Documenti/GitHub/EGT-paper/plot'
files = os.listdir(folder_path)         # Get a list of all files in the folder

for file_name in files:
    file_path = os.path.join(folder_path, file_name)  # Construct the file path

    if os.path.isfile(file_path) and file_name.endswith('.txt'):       # Check if the item in the folder is a file
        with open(file_path, 'r') as file:   # Open the file for reading      
            content = file.readlines()     # Read the contents of the file
       
        var_name = os.path.splitext(file_name)[0]     # Create a variable with the same name as the file (without the extension)
        array = []

        for line in content: # Iterate over the lines in the file           
            line = line.strip()  # Remove any trailing whitespace or newline characters
            array.append(float(line))   # Convert the line to a floating-point number and append it to the array

        locals()[var_name] = array  # Assign the array to the variable with the same name as the file

# %%
fig1,ax = plt.figure(figsize=(5, 5)), plt.axes()
plt.plot(np.arange(21),f42001_5_0, marker='o',linewidth=2, label='cn=0.2')
plt.plot(np.arange(21),f45001_5_0, marker='o',linewidth=2, label='cn=0.5')
plt.plot(np.arange(21),f475001_5_0, marker='o',linewidth=2, label='cn=0.75')
plt.legend()
plt.xlabel('Initial number of cooperators',fontsize=20)
plt.ylabel('Fixation probability',fontsize=20)
plt.title('beta=0.01')
ax.tick_params(labelsize=15)
plt.show()

# %%
fig1,ax = plt.figure(figsize=(5, 5)), plt.axes()
plt.plot(np.arange(21),f4201_5_0, marker='o',linewidth=2, label=r'$c_n$ = 0.2')
plt.plot(np.arange(21),f4501_5_0, marker='o',linewidth=2, label=r'$c_n$ = 0.5')
plt.plot(np.arange(21),f47501_5_0, marker='o',linewidth=2, label=r'$c_n$ = 0.75')
plt.legend(fontsize=15)
plt.xlabel('Initial number of cooperators',fontsize=20)
plt.ylabel('Fixation probability',fontsize=20)
plt.title(r'$\beta$ = 0.1')
ax.tick_params(labelsize=15)
plt.show()

# %%
fig1,ax = plt.figure(figsize=(5, 5)), plt.axes()
plt.plot(np.arange(21),f421_5_0, marker='o',linewidth=2, label=r'$c_n$ = 0.2')
plt.plot(np.arange(21),f451_5_0, marker='o',linewidth=2, label=r'$c_n$ = 0.5')
plt.plot(np.arange(21),f4751_5_0, marker='o',linewidth=2, label=r'$c_n$ = 0.75')
plt.legend()
plt.xlabel('Initial number of cooperators',fontsize=20)
plt.ylabel('Fixation probability',fontsize=20)
#plt.title('beta=1')
ax.tick_params(labelsize=15)
plt.savefig('beta=1.png')
plt.show()

# %%
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(4, 7))

# Create a grid for subplots without any space
gs = gridspec.GridSpec(3, 1)

# Create the subplots
axs[0] = plt.subplot(gs[0])
axs[1] = plt.subplot(gs[1])
axs[2] = plt.subplot(gs[2])

# Remove space between subplots
gs.update(hspace=0)

# Plot Figure 1
axs[0].plot(np.arange(21),f421_5_0, marker='o',linewidth=2, label=r'$c_n$ = 0.2')
axs[0].plot(np.arange(21),f451_5_0, marker='o',linewidth=2, label=r'$c_n$ = 0.5')
axs[0].plot(np.arange(21),f4751_5_0, marker='o',linewidth=2, label=r'$c_n$ = 0.75')
axs[0].set_xticks([])
axs[0].tick_params(axis='y', labelsize=12)
axs[0].set_ylabel('Fixation probability',fontsize=12)
axs[0].text(4, 0.85, r'$\beta$ = 1', fontsize=12, ha="center")

#plot figure 2
axs[1].plot(np.arange(21),f4201_5_0, marker='o',linewidth=2, label=r'$c_n$ = 0.2')
axs[1].plot(np.arange(21),f4501_5_0, marker='o',linewidth=2, label=r'$c_n$ = 0.5')
axs[1].plot(np.arange(21),f47501_5_0, marker='o',linewidth=2, label=r'$c_n$ = 0.75')
axs[1].set_xticks([])
axs[1].tick_params(axis='y', labelsize=12)
axs[1].set_ylabel('Fixation probability',fontsize=12)
axs[1].text(3, 0.9, r'$\beta$ = 0.1', fontsize=12, ha="center")

#plot figure 3
axs[2].plot(np.arange(21),f42001_5_0, marker='o',linewidth=2, label=r'$c_n$ = 0.2')
axs[2].plot(np.arange(21),f45001_5_0, marker='o',linewidth=2, label=r'$c_n$ = 0.5')
axs[2].plot(np.arange(21),f475001_5_0, marker='o',linewidth=2, label=r'$c_n$ = 0.75')
axs[2].legend(loc='lower right',fontsize=12)
axs[2].set_xlabel('Initial number of cooperators',fontsize=12)
axs[2].tick_params(axis='x', labelsize=12)
axs[2].tick_params(axis='y', labelsize=12)
axs[2].set_ylabel('Fixation probability',fontsize=12)
axs[2].text(4, 0.9, r'$\beta$ = 0.01', fontsize=12, ha="center")

#draw a line y=1/20x
x = np.linspace(0, 20, 1000)
y =1/20*x
axs[0].plot(x, y, '-k', alpha=0.2)
axs[1].plot(x, y, '-k', alpha=0.2)
axs[2].plot(x, y, '-k', alpha=0.2)
# no space between subplots
plt.tight_layout()
plt.savefig('beta.png')
plt.show()
# Out:
# /tmp/ipykernel_5898/2804460050.py:9: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   axs[0] = plt.subplot(gs[0])
# /tmp/ipykernel_5898/2804460050.py:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   axs[1] = plt.subplot(gs[1])
# /tmp/ipykernel_5898/2804460050.py:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   axs[2] = plt.subplot(gs[2])

# %%
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(4, 7))
xmin=-1
xmax=21

# Create a grid for subplots without any space
gs = gridspec.GridSpec(3, 1)

# Create the subplots
axs[0] = plt.subplot(gs[0])
axs[1] = plt.subplot(gs[1])
axs[2] = plt.subplot(gs[2])

# Remove space between subplots
gs.update(hspace=0)
# Plot Figure 1
axs[0].plot(np.arange(21),f4251_5_0, marker='o',linewidth=2, label=r'$\beta$ = 1')
axs[0].plot(np.arange(21),f4201_5_0, marker='o',linewidth=2, label=r'$\beta$ = 0.1')
axs[0].plot(np.arange(21),f42001_5_0, marker='o',linewidth=2, label=r'$\beta$ = 0.01')
axs[0].set_xticks([])
axs[0].tick_params(axis='y', labelsize=12)
axs[0].set_ylabel('Fixation probability',fontsize=12)
axs[0].text(15, 0.25, r'$c_n$ = 0.25' + '\n' +  'HG Game', fontsize=12, ha="center")
axs[0].set_xlim(right=xmax, left=xmin)
axs[0].axvspan(xmin, xmax, facecolor='moccasin', alpha=0.6)

#plot figure 2
axs[1].plot(np.arange(21),f451_5_0, marker='o',linewidth=2, label=r'$\beta$ = 1')
axs[1].plot(np.arange(21),f4501_5_0, marker='o',linewidth=2, label=r'$\beta$ = 0.1')
axs[1].plot(np.arange(21),f45001_5_0, marker='o',linewidth=2, label=r'$\beta$ = 0.01')
axs[1].tick_params(axis='y', labelsize=12)
axs[1].set_ylabel('Fixation probability',fontsize=12)
axs[1].text(4, 0.7, r'$c_n$ = 0.5' + '\n' +  'SD Game', fontsize=12, ha="center")
axs[1].set_xlim(right=xmax, left=xmin)
axs[1].axvspan(xmin, xmax, facecolor='lightskyblue', alpha=0.4)
#make legend transparent
leg = axs[1].legend(loc='lower right',fontsize=11)
leg.get_frame().set_alpha(0)
#axs[1].legend(loc='lower right',fontsize=12)

#plot figure 3
axs[2].plot(np.arange(21),f4751_5_0, marker='o',linewidth=2, label=r'$\beta$ = 1')
axs[2].plot(np.arange(21),f47501_5_0, marker='o',linewidth=2, label=r'$\beta$ = 0.1')
axs[2].plot(np.arange(21),f475001_5_0, marker='o',linewidth=2, label=r'$\beta$ = 0.01')
axs[2].set_xlabel('Initial number of cooperators',fontsize=12)
axs[2].tick_params(axis='x', labelsize=12)
axs[2].tick_params(axis='y', labelsize=12)
axs[2].set_ylabel('Fixation probability',fontsize=12)
axs[2].text(4, 0.7, r'$c_n$ = 0.75' + '\n' +  'PD Game', fontsize=12, ha="center")
axs[2].set_xlim(right=xmax, left=xmin)
axs[2].axvspan(xmin, xmax, facecolor='slateblue', alpha=0.2)

#draw a line y=1/20x
x = np.linspace(0, 20, 1000)
y = 1/20*x
axs[0].plot(x, y, '-k', alpha=0.2)
axs[1].plot(x, y, '-k', alpha=0.2)
axs[2].plot(x, y, '-k', alpha=0.2)

plt.tight_layout()
plt.savefig('c_n.pdf')
plt.show()
# Out:
# /tmp/ipykernel_218641/473992132.py:9: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   axs[0] = plt.subplot(gs[0])
# /tmp/ipykernel_218641/473992132.py:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   axs[1] = plt.subplot(gs[1])
# /tmp/ipykernel_218641/473992132.py:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   axs[2] = plt.subplot(gs[2])

# %%
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(4, 7))
xmin=-1
xmax=21

# Create a grid for subplots without any space
gs = gridspec.GridSpec(3, 1)

# Create the subplots
axs[0] = plt.subplot(gs[0])
axs[1] = plt.subplot(gs[1])
axs[2] = plt.subplot(gs[2])

# Remove space between subplots
gs.update(hspace=0)
# Plot Figure 1
axs[0].plot(np.arange(21),f421_5_0, marker='o',linewidth=2, label=r'$\beta$ = 1')
axs[0].plot(np.arange(21),f4201_5_0, marker='o',linewidth=2, label=r'$\beta$ = 0.1')
axs[0].plot(np.arange(21),f42001_5_0, marker='o',linewidth=2, label=r'$\beta$ = 0.01')
axs[0].set_xticks([])
axs[0].tick_params(axis='y', labelsize=12)
axs[0].set_ylabel('Fixation probability',fontsize=12)
axs[0].text(15, 0.25, r'$c_n$ = 0.2' + '\n' +  'HG Game', fontsize=12, ha="center")
axs[0].set_xlim(right=xmax, left=xmin)
axs[0].axvspan(xmin, xmax, facecolor='moccasin', alpha=0.6)

#plot figure 2
axs[1].plot(np.arange(21),f451_5_0, marker='o',linewidth=2, label=r'$\beta$ = 1')
axs[1].plot(np.arange(21),f4501_5_0, marker='o',linewidth=2, label=r'$\beta$ = 0.1')
axs[1].plot(np.arange(21),f45001_5_0, marker='o',linewidth=2, label=r'$\beta$ = 0.01')
axs[1].tick_params(axis='y', labelsize=12)
axs[1].set_ylabel('Fixation probability',fontsize=12)
axs[1].text(4, 0.7, r'$c_n$ = 0.5' + '\n' +  'SD Game', fontsize=12, ha="center")
axs[1].set_xlim(right=xmax, left=xmin)
axs[1].axvspan(xmin, xmax, facecolor='lightskyblue', alpha=0.4)
#make legend transparent
leg = axs[1].legend(loc='lower right',fontsize=11)
leg.get_frame().set_alpha(0)
#axs[1].legend(loc='lower right',fontsize=12)

#plot figure 3
axs[2].plot(np.arange(21),f4751_5_0, marker='o',linewidth=2, label=r'$\beta$ = 1')
axs[2].plot(np.arange(21),f47501_5_0, marker='o',linewidth=2, label=r'$\beta$ = 0.1')
axs[2].plot(np.arange(21),f475001_5_0, marker='o',linewidth=2, label=r'$\beta$ = 0.01')
axs[2].set_xlabel('Initial number of cooperators',fontsize=12)
axs[2].tick_params(axis='x', labelsize=12)
axs[2].tick_params(axis='y', labelsize=12)
axs[2].set_ylabel('Fixation probability',fontsize=12)
axs[2].text(4, 0.7, r'$c_n$ = 0.75' + '\n' +  'PD Game', fontsize=12, ha="center")
axs[2].set_xlim(right=xmax, left=xmin)
axs[2].axvspan(xmin, xmax, facecolor='slateblue', alpha=0.2)

#draw a line y=1/20x
x, y = np.linspace(0, 20, 1000), 1/20*x
axs[0].plot(x, y, '-k', alpha=0.2)
axs[1].plot(x, y, '-k', alpha=0.2)
axs[2].plot(x, y, '-k', alpha=0.2)

plt.tight_layout()
#plt.savefig('c_n.pdf')
plt.show()
# Out:
# /tmp/ipykernel_5898/4113663518.py:9: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   axs[0] = plt.subplot(gs[0])
# /tmp/ipykernel_5898/4113663518.py:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   axs[1] = plt.subplot(gs[1])
# /tmp/ipykernel_5898/4113663518.py:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   axs[2] = plt.subplot(gs[2])

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(12, 8))

# Plot Figure 1
axs[0,0].plot(np.arange(21),f421_5_0, marker='o',linewidth=2, label='beta=1')
axs[0,0].plot(np.arange(21),f4201_5_0, marker='o',linewidth=2, label='beta=0.1')
axs[0,0].plot(np.arange(21),f42001_5_0, marker='o',linewidth=2, label='beta=0.01')
axs[0,0].legend(loc='lower right')
axs[0,0].set_xlabel('Initial number of cooperators',fontsize=10)
axs[0,0].set_ylabel('Fixation probability',fontsize=10)
axs[0,0].set_title('cn=0.2, all alpha=0.5')

axs[0,1].plot(np.arange(21),f451_5_0, marker='o',linewidth=2, label='beta=1')
axs[0,1].plot(np.arange(21),f4501_5_0, marker='o',linewidth=2, label='beta=0.1')
axs[0,1].plot(np.arange(21),f45001_5_0, marker='o',linewidth=2, label='beta=0.01')
axs[0,1].legend(loc='lower right')
axs[0,1].set_xlabel('Initial number of cooperators',fontsize=10)
axs[0,1].set_ylabel('Fixation probability',fontsize=10)
axs[0,1].set_title('cn=0.5, all alpha=0.5')

axs[0,2].plot(np.arange(21),f4751_5_0, marker='o',linewidth=2, label='beta=1')
axs[0,2].plot(np.arange(21),f47501_5_0, marker='o',linewidth=2, label='beta=0.1')
axs[0,2].plot(np.arange(21),f475001_5_0, marker='o',linewidth=2, label='beta=0.01')
axs[0,2].legend(loc='lower right')
axs[0,2].set_xlabel('Initial number of cooperators',fontsize=10)
axs[0,2].set_ylabel('Fixation probability',fontsize=10)
axs[0,2].set_title('cn=0.75, all alpha=0.5')

# Plot Figure 1
axs[1,0].plot(np.arange(21),f421_82_0, marker='o',linewidth=2, label='beta=1')
axs[1,0].plot(np.arange(21),f4201_82_0, marker='o',linewidth=2, label='beta=0.1')
axs[1,0].plot(np.arange(21),f42001_82_0, marker='o',linewidth=2, label='beta=0.01')
axs[1,0].legend(loc='lower right')
axs[1,0].set_xlabel('Initial number of cooperators',fontsize=10)
axs[1,0].set_ylabel('Fixation probability',fontsize=10)
axs[1,0].set_title('cn=0.2, 50% alpha=0.8 , 50% alpha=0.2')

axs[1,1].plot(np.arange(21),f451_82_0, marker='o',linewidth=2, label='beta=1')
axs[1,1].plot(np.arange(21),f4501_82_0, marker='o',linewidth=2, label='beta=0.1')
axs[1,1].plot(np.arange(21),f45001_82_0, marker='o',linewidth=2, label='beta=0.01')
axs[1,1].legend(loc='lower right')
axs[1,1].set_xlabel('Initial number of cooperators',fontsize=10)
axs[1,1].set_ylabel('Fixation probability',fontsize=10)
axs[1,1].set_title('cn=0.5')

axs[1,2].plot(np.arange(21),f4751_82_0, marker='o',linewidth=2, label='beta=1')
axs[1,2].plot(np.arange(21),f47501_82_0, marker='o',linewidth=2, label='beta=0.1')
axs[1,2].plot(np.arange(21),f475001_82_0, marker='o',linewidth=2, label='beta=0.01')
axs[1,2].legend(loc='lower right')
axs[1,2].set_xlabel('Initial number of cooperators',fontsize=10)
axs[1,2].set_ylabel('Fixation probability',fontsize=10)
axs[1,2].set_title('cn=0.75')
plt.subplots_adjust(wspace=8)
plt.tight_layout(pad=2.0)
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))

# Plot Figure 1
axs[0].plot(np.arange(21),f421_82_0, marker='o',linewidth=2, label='beta=1')
axs[0].plot(np.arange(21),f4201_82_0, marker='o',linewidth=2, label='beta=0.1')
axs[0].plot(np.arange(21),f42001_82_0, marker='o',linewidth=2, label='beta=0.01')
axs[0].legend(loc='lower right')
axs[0].set_xlabel('Initial number of cooperators',fontsize=10)
axs[0].set_ylabel('Fixation probability',fontsize=10)
axs[0].set_title('cn=0.2')

axs[1].plot(np.arange(21),f451_82_0, marker='o',linewidth=2, label='beta=1')
axs[1].plot(np.arange(21),f4501_82_0, marker='o',linewidth=2, label='beta=0.1')
axs[1].plot(np.arange(21),f45001_82_0, marker='o',linewidth=2, label='beta=0.01')
axs[1].legend(loc='lower right')
axs[1].set_xlabel('Initial number of cooperators',fontsize=10)
axs[1].set_ylabel('Fixation probability',fontsize=10)
axs[1].set_title('cn=0.5')

axs[2].plot(np.arange(21),f4751_82_0, marker='o',linewidth=2, label='beta=1')
axs[2].plot(np.arange(21),f47501_82_0, marker='o',linewidth=2, label='beta=0.1')
axs[2].plot(np.arange(21),f475001_82_0, marker='o',linewidth=2, label='beta=0.01')
axs[2].legend(loc='lower right')
axs[2].set_xlabel('Initial number of cooperators',fontsize=10)
axs[2].set_ylabel('Fixation probability',fontsize=10)
axs[2].set_title('cn=0.75')
plt.subplots_adjust(wspace=8)
plt.tight_layout(pad=2.0)
plt.show()
